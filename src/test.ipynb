# %%
# %pip uninstall -y pytube
# %pip install -U pytubefix
# Out:
# WARNING: Skipping pytube as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytubefix in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (10.3.8)
# Requirement already satisfied: aiohttp>=3.12.13 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from pytubefix) (3.13.3)
# Requirement already satisfied: nodejs-wheel-binaries>=22.20.0 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from pytubefix) (24.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from aiohttp>=3.12.13->pytubefix) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/imasyma/miniconda3/envs/main_python/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.12.13->pytubefix) (3.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytubefix import YouTube

YouTube('https://www.youtube.com/watch?app=desktop&v=noN30ZLQr-M').streams.first().download()
yt = YouTube('https://www.youtube.com/watch?app=desktop&v=noN30ZLQr-M')
yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download()
# Out:
# '/Users/imasyma/VScodeProjects/pytopia/ProjectBasedPython/levelII/11-YouTube-Downloader/src/آموزش ایتالیایی در 90 روز درس 3.mp4'

# %%
from pytubefix import YouTube

# %%
yt = YouTube('https://www.youtube.com/watch?app=desktop&v=noN30ZLQr-M')
yt.streams.filter(progressive=True, file_extension='mp4')
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" sabr="False" type="video">]

# %%
yt.streams.filter(progressive=True, file_extension='mp4')
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" sabr="False" type="video">]

# %%
from tqdm.notebook import tqdm
import time
from pathlib import Path

# %%
class YouTubeDownloader:
    def __init__(self, url, output_path=None, quality=None):
        self.url = url
        self.output_path = output_path or Path().cwd()
        self.quality = quality or 'highest'
        self.yt = YouTube(
            self.url, 
            on_progress_callback = self.on_progress,
            on_complete_callback = self.on_complete
        )

    def download(self):
        if self.quality == 'highest':
            stream = self.yt.streams.filter().get_highest_resolution()
        else:
            stream = self.yt.streams.filter(
                progressive=True, 
                file_extension='mp4', 
                res=self.quality
            ).first()
            
        self.pbar = tqdm(desc='Downloading...', total=stream.filesize, unit='B', unit_scale=True)
        stream.download(output_path=self.output_path)
    
    def on_progress(self, stream, chunk, bytes_remaining):
        
        # total_size = stream.filesize
        # bytes_downloaded = total_size - bytes_remaining
        
        # print(
        #     f"\r{'downloading...':<15}"
        #     f"{(100*(total_size-bytes_remaining)/total_size):>3.0f}% "
        #     f"| {bytes_downloaded/1024/1024:>5.1f}MB",
        #     f" of {total_size/1024/1024:>5.1f}MB",
        #     end=''
        # )
        
        current_size = stream.filesize - bytes_remaining
        self.pbar.update(current_size - self.pbar.n)
    
    def on_complete(self, stream, file_path):
        # print(f"\nDownload completed. File saved to :{file_path}")
        pass

# %%
YouTubeDownloader('https://www.youtube.com/watch?app=desktop&v=noN30ZLQr-M').download()
# Out:
# Downloading...:   0%|          | 0.00/31.4M [00:00<?, ?B/s]

# %%
YouTubeDownloader('https://www.youtube.com/watch?app=desktop&v=noN30ZLQr-M').yt.streams.filter(progressive=True, file_extension='mp4')
# Out:
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" sabr="False" type="video">]
